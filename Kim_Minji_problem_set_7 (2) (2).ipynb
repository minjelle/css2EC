# %% [markdown]
# Block 1

# %%
import numpy as np
from google.colab import files
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale=2, style="white")

# %% [markdown]
# Block 2

# %%
#import csv file
files.upload()
data = pd.read_csv('avocado.csv')
print(data)
# Out:
#      <input type="file" id="files-b83ca0ec-6787-4017-a461-f66a7867c3e5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b83ca0ec-6787-4017-a461-f66a7867c3e5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving avocado.csv to avocado (1).csv
#        Unnamed: 0        Date  ...  year            region
# 0               0  2015-12-27  ...  2015            Albany
# 1               1  2015-12-20  ...  2015            Albany
# 2               2  2015-12-13  ...  2015            Albany
# 3               3  2015-12-06  ...  2015            Albany
# 4               4  2015-11-29  ...  2015            Albany
# ...           ...         ...  ...   ...               ...
# 18244           7  2018-02-04  ...  2018  WestTexNewMexico
# ...

# %% [markdown]
# Block 3

# %%
#show the first 5 and last 5 rows of the dataset
print(data.head())
print(data.tail())
# Out:
#    Unnamed: 0        Date  AveragePrice  ...          type  year  region
# 0           0  2015-12-27          1.33  ...  conventional  2015  Albany
# 1           1  2015-12-20          1.35  ...  conventional  2015  Albany
# 2           2  2015-12-13          0.93  ...  conventional  2015  Albany
# 3           3  2015-12-06          1.08  ...  conventional  2015  Albany
# 4           4  2015-11-29          1.28  ...  conventional  2015  Albany
#
# [5 rows x 14 columns]
#        Unnamed: 0        Date  AveragePrice  ...     type  year            region
# 18244           7  2018-02-04          1.63  ...  organic  2018  WestTexNewMexico
# 18245           8  2018-01-28          1.71  ...  organic  2018  WestTexNewMexico
# 18246           9  2018-01-21          1.87  ...  organic  2018  WestTexNewMexico
# 18247          10  2018-01-14          1.93  ...  organic  2018  WestTexNewMexico
# 18248          11  2018-01-07          1.62  ...  organic  2018  WestTexNewMexico
#
# ...

# %% [markdown]
# Block 4

# %%
#visualize dataset with at least 3 visualizations

#1. histogram for the features you are interested in
sns.histplot(data['AveragePrice'], kde=False, bins=30, color='dimgrey')

# %%
#2. scatterplot for any relationships you are interested in
sns.scatterplot(x= '4046',y = 'Total Bags',data=data)

# %%
#3. countplot to differentiate types
sns.countplot(data['region'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Block 5

# %%
#start working on feature engineering
#1. check for missing data
sns.heatmap(data.isnull(),cmap=['Green', 'Red'])
print('There is no missing data')

#2. check for duplicates
any(data.duplicated())
print('There are no duplicates')

#3. check for outliers

#4. list variables for dummy coding
pd.get_dummies(data['type'])
# Out:
# There is no missing data
# There are no duplicates
#        conventional  organic
# 0                 1        0
# 1                 1        0
# 2                 1        0
# 3                 1        0
# 4                 1        0
# ...             ...      ...
# 18244             0        1
# 18245             0        1
# 18246             0        1
# 18247             0        1
# 18248             0        1
#
# [18249 rows x 2 columns]

# %% [markdown]
# Block 6

# %% [markdown]
# 1. I will handle feature engineering by using it to make different plots according to each avocado code (i.e. 4046, etc). I have already checked that there are no outliers, duplicates, and missing data, so I will proceed to use my clean data using selective features to make more simplistic data visualizations.
#
# 2. I want to analyze the relationships between prices. For example, I want to see if I can find predict the price of an avocado using variables like Region and type to see if location of avocados sold affects the prices based on specific factors (i.e. amount of supply/demand or expensive delivery methods).
